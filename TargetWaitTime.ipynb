# %% [markdown]
# ## Target Wait Time Scheduler
#
# #### Sets
# Define the sets used in the model:
# - $I$: Range of surgeries.
# - $J$: Range of days.
# - $K$: Range of rooms.
#
# #### Variables
# Define the decision variables:
# - $X_{ijk}$: Binary variable indicating if surgery $i$ is scheduled on day $j$ in room $k$.
# - $SWT_{i}$: Scheduled wait time for surgery $i$.
#   - $SWT_{i} = j$ (where $X_{ijk} = 1$) - $AD_i$
# - $Y_i$: Binary variable indicating whether the scheduled wait time for surgery $i$ exceeds the target wait time.
#
# #### Parameters
# Define the constants used in the model:
# - $C_{jk}$: Room capacity on day $j$.
# - $D_i$: Surgery $i$ duration.
# - $T_i$: Target wait time for surgery $i$.
# - $AD_i$: Admitted date for surgery $i$.
# - $M$: A sufficiently large constant.
#
# #### Constraints
# Define the constraints:
# - **Constraint 1: Surgery can only be done once**
#   - $\sum_{jk} (X_{ijk}) \leq 1$ for all $i \in I$
# - **Constraint 2: Room capacity**
#   - $C_{jk} \geq \sum_{i \in I} (X_{ijk} \cdot D_i)$ for all $j$ in $J$, $k$ in $K$
# - **Constraint 3: Set $SWT_{i}$**
#   - $SWT_{i} = \sum_{jk} (j \cdot X_{ijk}) \cdot (1 + AD_i)$ for all $i \in I$
# - **Constraint 4: Indicator for $SWT_{i} > T_{i}$**
#   - $SWT_{i} - T_{i} \leq M \cdot Y_{i}$ for all $i \in I$
# - **Constraint 5: Enforce $SWT_{i} > T_{i}$**
#   - $SWT_{i} - T_{i} \leq M \cdot Y_{i}$ for all $i \in I$
#
# #### Objective Function
# Define the objective function:
# - **Minimize** $\text{Minimize} \sum_{i,j,k} \left( \text{max}\left(0, X_{ijk} \cdot (SWT_i - T_i)\right) + \beta \cdot SWT_i + \delta \cdot {penalty\_unscheduled}\right) $

# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd
import sys as sys

# Create a new model
model = gp.Model("Rolling_Horizon_Scheduler")

#Read In Surgical Information
surgicalPortfolio = pd.read_csv('surgeries_data.csv')
surgicalPortfolio['ID'] = pd.Series(surgicalPortfolio['id'] +" " + surgicalPortfolio['type'])
surgeries = surgicalPortfolio['ID']

#read in capacity information
caps = pd.read_csv('OR_caps.csv')
rooms = caps['room'].unique().tolist()
days = caps['day'].unique().tolist()

# Sets
I = surgeries
J = days
K = rooms 

# Parameters

C = {(row['day'], row['room']): row['capacity'] for _, row in caps.iterrows()} #capacities for each room on each day
D = {row['ID']: row['duration'] for _, row in surgicalPortfolio.iterrows()} # 
T = {row['ID']: row['ideal_waiting_time'] for _, row in surgicalPortfolio.iterrows()}
AD = {row['ID']: row['days_waited'] for _, row in surgicalPortfolio.iterrows()}
M = 10**99

# Variables
X = {(i, j, k): model.addVar(vtype=GRB.BINARY, name=f"X_{i}_{j}_{k}") for i in I for j in J for k in K}

SWT = {i: model.addVar(vtype=GRB.CONTINUOUS, name=f"SWT_{i}") for i in I}

Y = {i: model.addVar(vtype=GRB.BINARY, name=f"Y_{i}") for i in I}

# Constraints
# Constraint 1: Surgery can only be done once
for i in I:
    model.addConstr(gp.quicksum(X[i, j, k] for j in J for k in K) <= 1, name=f"One Surgery{i}")

# Constraint 2: Room capacity
for j in J:
    for k in K:
        model.addConstr(gp.quicksum(X[i, j, k] * D[i] for i in I) <= C[j, k], name=f"Capacity{j}_{k}")

#Constraints for variables: 

# Constraint 3: Add constraint to set SWT[i] equal to the scheduled wait time plus the admitted date
for i in I:
    model.addConstr(SWT[i] == gp.quicksum(j * X[i, j, k] for j in J for k in K) * (1 + AD[i]),
                    name=f"SWT_Constraint_{i}")
    
# Constraint 4 Define a new binary decision variable to indicate whether SWT[i] > T[i]
for i in I:
    model.addConstr(SWT[i] - T[i] <= M * Y[i], name=f"Constraint_SWT_T_{i}")

# Define the penalty term for surgeries not scheduled at least once
penalty_unscheduled = gp.quicksum((1 - gp.quicksum(X[i, j, k] for j in J for k in K)) for i in I)

# Define the penalty term for surgeries exceeding target wait time
penalty_term = gp.quicksum((SWT[i] - T[i]) * Y[i] for i in I for j in J for k in K)

# Define the cost term for each scheduled surgery
cost_term = gp.quicksum(SWT[i] for i in I)

# Combine the penalty term and cost term to form the objective function
beta = 0.1
delta = 99999999
model.setObjective(penalty_term + (beta * cost_term) + delta * penalty_unscheduled, GRB.MINIMIZE)

# %%
# Optimize the model
model.optimize()

# Check if the optimization was successful
if model.status == GRB.OPTIMAL:
    # Extract and print the schedule results
    print("Schedule Results:")
    for i in I:
        for j in J:
            for k in K:
                # Check if surgery i is scheduled on day j in room k
                if X[i, j, k].x > 0.5:  # Assuming x > 0.5 indicates scheduling
                    print(f"Surgery {i} is scheduled on day {j} in room {k}")
    
    # Extract and print the scheduled wait times
    print("\nScheduled Wait Times:")
    for i in I:
        print(f"Scheduled wait time for Surgery {i}: {SWT[i].x}")
else:
    print("No feasible solution found.")
    # Print all constraints
    for constr in model.getConstrs():
        print(constr)
# Out:
# Gurobi Optimizer version 11.0.1 build v11.0.1rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: 13th Gen Intel(R) Core(TM) i7-1355U, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 132 rows, 936 columns and 2700 nonzeros
# Model fingerprint: 0x0daddb2f
# Model has 36 quadratic objective terms
# Variable types: 36 continuous, 900 integer (900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+99]
#   Objective range  [1e-01, 1e+08]
#   QObjective range [5e+01, 5e+01]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Warning: Model contains large matrix coefficient range
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.600000e+09
# Found heuristic solution: objective 3.599998e+09
# Presolve removed 6 rows and 6 columns
# Presolve time: 0.01s
# Presolved: 156 rows, 960 columns, 2778 nonzeros
# Variable types: 0 continuous, 960 integer (894 binary)
# Found heuristic solution: objective 2.999998e+09
#
# Root relaxation: objective 1.199998e+09, 323 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1.2000e+09    0   91 3.0000e+09 1.2000e+09  60.0%     -    0s
# H    0     0                    1.300000e+09 1.2000e+09  7.69%     -    0s
# H    0     0                    1.200000e+09 1.2000e+09  0.00%     -    0s
#
# Explored 1 nodes (369 simplex iterations) in 0.05 seconds (0.02 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: 1.2e+09 1.3e+09 3e+09 ... 3.6e+09
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.200000430800e+09, best bound 1.199998162800e+09, gap 0.0002%
# Schedule Results:
# Surgery S1 Tonsillectomy is scheduled on day 1 in room 0
# Surgery S2 Tonsillectomy is scheduled on day 8 in room 1
# Surgery S4 Tonsillectomy is scheduled on day 3 in room 1
# Surgery S5 Tonsillectomy is scheduled on day 7 in room 0
# Surgery S6 Tonsillectomy is scheduled on day 8 in room 2
# Surgery S7 Tonsillectomy is scheduled on day 1 in room 2
# Surgery S8 Tonsillectomy is scheduled on day 7 in room 1
# Surgery S10 Tonsillectomy is scheduled on day 3 in room 0
# Surgery S12 Tonsillectomy is scheduled on day 4 in room 0
# Surgery S13 Tonsillectomy is scheduled on day 4 in room 1
# Surgery S14 Tonsillectomy is scheduled on day 7 in room 2
# Surgery S18 Tonsillectomy is scheduled on day 6 in room 0
# Surgery S19 Tonsillectomy is scheduled on day 8 in room 0
# Surgery S20 Tonsillectomy is scheduled on day 6 in room 1
# Surgery S21 Tonsillectomy is scheduled on day 1 in room 1
# Surgery S22 Tonsillectomy is scheduled on day 2 in room 2
# Surgery S23 Tonsillectomy is scheduled on day 3 in room 2
# Surgery S24 Tonsillectomy is scheduled on day 4 in room 2
# Surgery S25 Tonsillectomy is scheduled on day 6 in room 2
# Surgery S26 Tonsillectomy is scheduled on day 2 in room 0
# Surgery S27 Tonsillectomy is scheduled on day 5 in room 2
# Surgery S28 Tonsillectomy is scheduled on day 5 in room 1
# Surgery S29 Tonsillectomy is scheduled on day 5 in room 0
# Surgery S30 Tonsillectomy is scheduled on day 2 in room 1
#
# Scheduled Wait Times:
# Scheduled wait time for Surgery S1 Tonsillectomy: 1.0
# Scheduled wait time for Surgery S2 Tonsillectomy: 8.0
# Scheduled wait time for Surgery S3 Tonsillectomy: 0.0
# Scheduled wait time for Surgery S4 Tonsillectomy: 3.0
# Scheduled wait time for Surgery S5 Tonsillectomy: 7.0
# Scheduled wait time for Surgery S6 Tonsillectomy: 8.0
# Scheduled wait time for Surgery S7 Tonsillectomy: 1.0
# Scheduled wait time for Surgery S8 Tonsillectomy: 7.0
# Scheduled wait time for Surgery S9 Tonsillectomy: -0.0
# Scheduled wait time for Surgery S10 Tonsillectomy: 3.0
# Scheduled wait time for Surgery S11 Tonsillectomy: -0.0
# Scheduled wait time for Surgery S12 Tonsillectomy: 4.0
# Scheduled wait time for Surgery S13 Tonsillectomy: 4.0
# Scheduled wait time for Surgery S14 Tonsillectomy: 7.0
# Scheduled wait time for Surgery S15 Tonsillectomy: -0.0
# Scheduled wait time for Surgery S16 Tonsillectomy: -0.0
# Scheduled wait time for Surgery S17 Tonsillectomy: -0.0
# Scheduled wait time for Surgery S18 Tonsillectomy: 6.0
# Scheduled wait time for Surgery S19 Tonsillectomy: 8.0
# Scheduled wait time for Surgery S20 Tonsillectomy: 6.0
# Scheduled wait time for Surgery S21 Tonsillectomy: 1.0
# Scheduled wait time for Surgery S22 Tonsillectomy: 2.0
# Scheduled wait time for Surgery S23 Tonsillectomy: 3.0
# Scheduled wait time for Surgery S24 Tonsillectomy: 4.0
# Scheduled wait time for Surgery S25 Tonsillectomy: 6.0
# Scheduled wait time for Surgery S26 Tonsillectomy: 2.0
# Scheduled wait time for Surgery S27 Tonsillectomy: 5.0
# Scheduled wait time for Surgery S28 Tonsillectomy: 5.0
# Scheduled wait time for Surgery S29 Tonsillectomy: 5.0
# Scheduled wait time for Surgery S30 Tonsillectomy: 2.0
# Scheduled wait time for Surgery S31 ACL Reconstruction: -0.0
# Scheduled wait time for Surgery S32 ACL Reconstruction: -0.0
# Scheduled wait time for Surgery S33 ACL Reconstruction: -0.0
# Scheduled wait time for Surgery S34 Gastric Bypass: -0.0
# Scheduled wait time for Surgery S35 Gastric Bypass: -0.0
# Scheduled wait time for Surgery S36 Gastric Bypass: -0.0
